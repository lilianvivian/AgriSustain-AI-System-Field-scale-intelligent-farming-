# %%
import kagglehub

path = kagglehub.dataset_download(
    "emmarex/plantdisease"
)

print(path)
# Out:
# ...
# 100%|██████████| 658M/658M [00:03<00:00, 220MB/s]
# Extracting files...
# /teamspace/studios/this_studio/.cache/kagglehub/datasets/emmarex/plantdisease/versions/1

# %%
import os

dataset_path = "/teamspace/studios/this_studio/.cache/kagglehub/datasets/emmarex/plantdisease/versions/1"

print("Number of items:", len(os.listdir(dataset_path)))

for item in os.listdir(dataset_path)[:20]:
    print(item)
# Out:
# Number of items: 2
# PlantVillage
# plantvillage

# %%
import os

for root, dirs, files in os.walk(dataset_path):
    print(root)
    print("Folders:", len(dirs))
    print("Files:", len(files))
    print("-"*50)

    if len(dirs) > 0:
        print("Sample folders:", dirs[:5])

    break
# Out:
# /teamspace/studios/this_studio/.cache/kagglehub/datasets/emmarex/plantdisease/versions/1
# Folders: 2
# Files: 0
# --------------------------------------------------
# Sample folders: ['PlantVillage', 'plantvillage']

# %%
import os

dataset_path = "/teamspace/studios/this_studio/.cache/kagglehub/datasets/emmarex/plantdisease/versions/1"

for item in os.listdir(dataset_path):
    print(item)
# Out:
# PlantVillage
# plantvillage

# %%
import os

base_path = "/teamspace/studios/this_studio/.cache/kagglehub/datasets/emmarex/plantdisease/versions/1"

for folder in os.listdir(base_path):
    folder_path = os.path.join(base_path, folder)

    if os.path.isdir(folder_path):
        print(f"\n{folder}")
        print("-"*50)

        items = os.listdir(folder_path)[:10]

        for item in items:
            print(item)
# Out:
# PlantVillage
# --------------------------------------------------
# Tomato__Tomato_YellowLeaf__Curl_Virus
# Pepper__bell___healthy
# Potato___Late_blight
# Potato___Early_blight
# Tomato_Early_blight
# Tomato_Spider_mites_Two_spotted_spider_mite
# Pepper__bell___Bacterial_spot
# Tomato_Septoria_leaf_spot
# Tomato_Leaf_Mold
# Tomato__Tomato_mosaic_virus
#
# plantvillage
# --------------------------------------------------
# PlantVillage

# %%
import os

plantvillage_path = "/teamspace/studios/this_studio/.cache/kagglehub/datasets/emmarex/plantdisease/versions/1/PlantVillage"

print("Number of classes:", len(os.listdir(plantvillage_path)))

print("\nFirst 20 classes:")
for cls in os.listdir(plantvillage_path)[:20]:
    print(cls)
# Out:
# Number of classes: 15
#
# First 20 classes:
# Tomato__Tomato_YellowLeaf__Curl_Virus
# Pepper__bell___healthy
# Potato___Late_blight
# Potato___Early_blight
# Tomato_Early_blight
# Tomato_Spider_mites_Two_spotted_spider_mite
# Pepper__bell___Bacterial_spot
# Tomato_Septoria_leaf_spot
# Tomato_Leaf_Mold
# Tomato__Tomato_mosaic_virus
# Tomato__Target_Spot
# Tomato_Bacterial_spot
# Tomato_Late_blight
# Tomato_healthy
# Potato___healthy
